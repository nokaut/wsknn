# %%
import numpy as np
import pandas as pd  # Optional dependency
from wsknn import fit
from wsknn.utils import load_gzipped_pickle
from wsknn.evaluate import score_model

# %%
# Load data
ITEMS = 'demo-data/recsys-2015/parsed_items.pkl.gz'
SESSIONS = 'demo-data/recsys-2015/parsed_sessions.pkl.gz'

items = load_gzipped_pickle(ITEMS)
sessions = load_gzipped_pickle(SESSIONS)

imap = items['map']
smap = sessions['map']

# %%
def get_sample_sessions(set_of_sessions, n_sessions=1000):
    sessions_keys = list(set_of_sessions.keys())
    key_sample = np.random.choice(sessions_keys, n_sessions)
    sampled = [set_of_sessions[dk] for dk in key_sample]
    return sampled

test_sessions = get_sample_sessions(smap)

# %%
session_selection = ['random', 'recent', 'common_items']
items_weighting = ['linear', 'log', 'quadratic']
ranking_methods = ['linear', 'log', 'quadratic', 'inv']

# %%
# Show different recommendations

for session in test_sessions:
    if len(session[0]) > 4:
        print('Session:')
        print(session)
        print('')
        for s_selection in session_selection:
            for i_weight in items_weighting:
                for rank_method in ranking_methods:
                    print('Session selection:', s_selection)
                    print('Item weighting:', i_weight)
                    print('Ranking:', rank_method)
                    fitted = fit(smap, imap,
                                 number_of_neighbors=1000,
                                 sampling_strategy=s_selection,
                                 sample_size=10000,
                                 weighting_func=i_weight,
                                 ranking_strategy=rank_method)
                    recommends = fitted.recommend(session)
                    print('Recommendations:', recommends)
        break
# Out:
# Session:
# [[214821341, 214821341, 214612721, 214580465, 214539592, 214510455, 214710013], [1397897051.836, 1397897131.162, 1397897223.089, 1397897413.903, 1397897611.54, 1397897677.988, 1397897887.507]]
#
# Session selection: random
# Item weighting: linear
# Ranking: linear
# Recommendations: [(214710013, 193.0952380952423), (214853081, 52.92857142857128), (214854716, 45.69047619047607), (214851757, 44.57142857142845), (214854720, 43.23809523809512)]
# Session selection: random
# Item weighting: linear
# Ranking: log
# Recommendations: [(214710013, 192.5238095238137), (214853081, 51.59523809523795), (214851757, 46.47619047619035), (214854716, 43.97619047619036), (214854720, 42.28571428571417)]
# Session selection: random
# Item weighting: linear
# Ranking: quadratic
# Recommendations: [(214710013, 188.5238095238134), (214853081, 50.833333333333194), (214854720, 48.190476190476055), (214854716, 46.07142857142845), (214851757, 44.95238095238083)]
# Session selection: random
# Item weighting: linear
# Ranking: inv
# Recommendations: [(214710013, 192.1428571428613), (214853081, 51.02380952380938), (214851757, 45.14285714285702), (214854720, 43.99999999999988), (214854716, 41.88095238095227)]
# Session selection: random
# Item weighting: log
# Ranking: linear
# Recommendations: [(214710013, 353.72193606191075), (214853081, 94.69464258316701), (214854720, 87.35258500534682), (214851757, 82.04903520145075), (214854716, 80.34386076085998)]
# Session selection: random
# Item weighting: log
# Ranking: log
# Recommendations: [(214710013, 351.2261479189007), (214853081, 92.51082795803333), (214851757, 81.73706168357451), (214854720, 77.99337946905963), (214854716, 75.35228447484015)]
# Session selection: random
# Item weighting: log
# Ranking: quadratic
# Recommendations: [(214710013, 350.6022008831482), (214853081, 95.00661610104325), (214851757, 79.86522057631707), (214854716, 79.40794020723126), (214854720, 70.19404152215364)]
# Session selection: random
# Item weighting: log
# Ranking: inv
# Recommendations: [(214710013, 347.1704921865094), (214853081, 89.0791192613947), (214854716, 80.34386076085998), (214854720, 76.43351187967843), (214851757, 72.06588262941108)]
# Session selection: random
# Item weighting: quadratic
# Ranking: linear
# Recommendations: [(214710013, 168.84693877550933), (214853081, 44.45578231292509), (214851757, 39.99999999999997), (214854720, 36.16666666666669), (214854716, 35.62244897959188)]
# Session selection: random
# Item weighting: quadratic
# Ranking: log
# Recommendations: [(214710013, 167.8469387755094), (214853081, 44.62244897959175), (214851757, 41.83333333333328), (214854716, 40.455782312925145), (214854720, 39.333333333333314)]
# Session selection: random
# Item weighting: quadratic
# Ranking: quadratic
# Recommendations: [(214710013, 169.68027210884262), (214853081, 45.955782312925066), (214851757, 40.166666666666636), (214854716, 39.95578231292515), (214854720, 39.66666666666664)]
# Session selection: random
# Item weighting: quadratic
# Ranking: inv
# Recommendations: [(214710013, 168.68027210884267), (214853081, 44.28911564625842), (214854720, 43.49999999999992), (214854716, 41.289115646258466), (214851757, 39.333333333333314)]
# Session selection: recent
# Item weighting: linear
# Ranking: linear
# Recommendations: [(214710013, 192.9047619047661), (214853081, 60.54761904761887), (214854716, 54.83333333333318), (214854720, 54.47619047619032), (214851757, 50.66666666666652)]
# Session selection: recent
# Item weighting: linear
# Ranking: log
# Recommendations: [(214710013, 192.9047619047661), (214853081, 60.54761904761887), (214854716, 54.83333333333318), (214854720, 54.47619047619032), (214851757, 50.66666666666652)]
# Session selection: recent
# Item weighting: linear
# Ranking: quadratic
# Recommendations: [(214710013, 192.9047619047661), (214853081, 60.54761904761887), (214854716, 54.83333333333318), (214854720, 54.47619047619032), (214851757, 50.66666666666652)]
# Session selection: recent
# Item weighting: linear
# Ranking: inv
# Recommendations: [(214710013, 192.9047619047661), (214853081, 60.54761904761887), (214854716, 54.83333333333318), (214854720, 54.47619047619032), (214851757, 50.66666666666652)]
# Session selection: recent
# Item weighting: log
# Ranking: linear
# Recommendations: [(214710013, 349.66628032951945), (214853081, 111.8531860663602), (214854716, 102.493980530073), (214854720, 102.01534034553009), (214851757, 96.71179054163402)]
# Session selection: recent
# Item weighting: log
# Ranking: log
# Recommendations: [(214710013, 349.66628032951945), (214853081, 111.8531860663602), (214854716, 102.493980530073), (214854720, 102.01534034553009), (214851757, 96.71179054163402)]
# Session selection: recent
# Item weighting: log
# Ranking: quadratic
# Recommendations: [(214710013, 349.66628032951945), (214853081, 111.8531860663602), (214854716, 102.493980530073), (214854720, 102.01534034553009), (214851757, 96.71179054163402)]
# Session selection: recent
# Item weighting: log
# Ranking: inv
# Recommendations: [(214710013, 349.66628032951945), (214853081, 111.8531860663602), (214854716, 102.493980530073), (214854720, 102.01534034553009), (214851757, 96.71179054163402)]
# Session selection: recent
# Item weighting: quadratic
# Ranking: linear
# Recommendations: [(214710013, 168.51360544217602), (214853081, 53.12244897959163), (214854716, 47.95578231292504), (214854720, 47.66666666666653), (214851757, 44.33333333333324)]
# Session selection: recent
# Item weighting: quadratic
# Ranking: log
# Recommendations: [(214710013, 168.51360544217602), (214853081, 53.12244897959163), (214854716, 47.95578231292504), (214854720, 47.66666666666653), (214851757, 44.33333333333324)]
# Session selection: recent
# Item weighting: quadratic
# Ranking: quadratic
# Recommendations: [(214710013, 168.51360544217602), (214853081, 53.12244897959163), (214854716, 47.95578231292504), (214854720, 47.66666666666653), (214851757, 44.33333333333324)]
# Session selection: recent
# Item weighting: quadratic
# Ranking: inv
# Recommendations: [(214710013, 168.51360544217602), (214853081, 53.12244897959163), (214854716, 47.95578231292504), (214854720, 47.66666666666653), (214851757, 44.33333333333324)]
# Session selection: common_items
# Item weighting: linear
# Ranking: linear
# Recommendations: [(214710013, 193.85714285714712), (214853081, 51.59523809523795), (214851757, 46.857142857142726), (214854716, 43.40476190476179), (214539592, 41.33333333333324)]
# Session selection: common_items
# Item weighting: linear
# Ranking: log
# Recommendations: [(214710013, 193.85714285714712), (214853081, 51.59523809523795), (214851757, 46.857142857142726), (214854716, 43.40476190476179), (214854720, 41.14285714285703)]
# Session selection: common_items
# Item weighting: linear
# Ranking: quadratic
# Recommendations: [(214710013, 193.85714285714712), (214853081, 51.59523809523795), (214851757, 46.857142857142726), (214854716, 43.40476190476179), (214854720, 41.14285714285703)]
# Session selection: common_items
# Item weighting: linear
# Ranking: inv
# Recommendations: [(214710013, 193.85714285714712), (214853081, 51.59523809523795), (214851757, 46.857142857142726), (214854716, 43.40476190476179), (214854720, 41.14285714285703)]
# Session selection: common_items
# Item weighting: log
# Ranking: linear
# Recommendations: [(214710013, 349.9782538473957), (214853081, 94.38266906529077), (214851757, 86.10469093384187), (214854716, 76.91215206422135), (214854720, 75.18561780817348)]
# Session selection: common_items
# Item weighting: log
# Ranking: log
# Recommendations: [(214710013, 349.9782538473957), (214853081, 94.38266906529077), (214851757, 86.10469093384187), (214854716, 76.91215206422135), (214854720, 75.18561780817348)]
# Session selection: common_items
# Item weighting: log
# Ranking: quadratic
# Recommendations: [(214710013, 349.9782538473957), (214853081, 94.38266906529077), (214851757, 86.10469093384187), (214854716, 76.91215206422135), (214854720, 75.18561780817348)]
# Session selection: common_items
# Item weighting: log
# Ranking: inv
# Recommendations: [(214710013, 349.9782538473957), (214853081, 94.38266906529077), (214851757, 86.10469093384187), (214854716, 76.91215206422135), (214854720, 75.18561780817348)]
# Session selection: common_items
# Item weighting: quadratic
# Ranking: linear
# Recommendations: [(214710013, 169.3469387755093), (214853081, 45.122448979591745), (214851757, 40.99999999999996), (214854716, 37.95578231292518), (214854720, 36.00000000000003)]
# Session selection: common_items
# Item weighting: quadratic
# Ranking: log
# Recommendations: [(214710013, 169.3469387755093), (214853081, 45.122448979591745), (214851757, 40.99999999999996), (214854716, 37.95578231292518), (214854720, 36.00000000000003)]
# Session selection: common_items
# Item weighting: quadratic
# Ranking: quadratic
# Recommendations: [(214710013, 169.3469387755093), (214853081, 45.122448979591745), (214851757, 40.99999999999996), (214854716, 37.95578231292518), (214854720, 36.00000000000003)]
# Session selection: common_items
# Item weighting: quadratic
# Ranking: inv
# Recommendations: [(214710013, 169.3469387755093), (214853081, 45.122448979591745), (214851757, 40.99999999999996), (214854716, 37.95578231292518), (214854720, 36.00000000000003)]

# %%
# Show different recommendations

columns = ['session weighting', 'items weighting', 'ranking', 'MRR', 'Recall', 'Precision', 'k']
data = []

for s_selection in session_selection:
    for i_weight in items_weighting:
        for rank_method in ranking_methods:
            fitted = fit(smap, imap,
                         number_of_neighbors=1000,
                         sampling_strategy=s_selection,
                         sample_size=10000,
                         weighting_func=i_weight,
                         ranking_strategy=rank_method)
            scores = score_model(test_sessions, fitted, k=fitted.n_of_recommendations, skip_short_sessions=True)
            data.append([s_selection, i_weight, rank_method, scores['MRR'], scores['Recall'], scores['Precision'], fitted.n_of_recommendations])

# %%
scores_frame = pd.DataFrame(data=data, columns=columns)
scores_frame.head()
# Out:
#   session weighting items weighting    ranking       MRR    Recall  Precision  \
# 0            random          linear     linear  0.386028  0.297037   0.186826
# 1            random          linear        log  0.396307  0.297695   0.185629
# 2            random          linear  quadratic  0.393812  0.309103   0.195210
# 3            random          linear        inv  0.379341  0.303166   0.186826
# 4            random             log     linear  0.388822  0.306845   0.186826
#
#    k
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5

# %%
scores_frame.sort_values('MRR', ascending=False).head(10)
# Out:
#    session weighting items weighting    ranking       MRR    Recall  \
# 22            recent       quadratic  quadratic  0.407385  0.308877
# 18            recent             log  quadratic  0.406088  0.310018
# 6             random             log  quadratic  0.405190  0.310498
# 10            random       quadratic  quadratic  0.400998  0.309200
# 30      common_items             log  quadratic  0.400898  0.287325
# 14            recent          linear  quadratic  0.399501  0.311288
# 21            recent       quadratic        log  0.399501  0.313971
# 34      common_items       quadratic  quadratic  0.399501  0.282335
# 20            recent       quadratic     linear  0.399202  0.311975
# 23            recent       quadratic        inv  0.397405  0.309875
#
#     Precision  k
# 22   0.190419  5
# 18   0.190419  5
# 6    0.194012  5
# 10   0.192814  5
# 30   0.184431  5
# 14   0.194012  5
# 21   0.189222  5
# 34   0.182036  5
# 20   0.188024  5
# 23   0.188024  5

# %%
scores_frame.sort_values('Recall', ascending=False).head(10)
# Out:
#    session weighting items weighting    ranking       MRR    Recall  \
# 21            recent       quadratic        log  0.399501  0.313971
# 9             random       quadratic        log  0.392116  0.313864
# 20            recent       quadratic     linear  0.399202  0.311975
# 7             random             log        inv  0.391517  0.311515
# 16            recent             log     linear  0.386926  0.311508
# 17            recent             log        log  0.386427  0.311315
# 14            recent          linear  quadratic  0.399501  0.311288
# 11            random       quadratic        inv  0.397106  0.311154
# 8             random       quadratic     linear  0.387425  0.310570
# 6             random             log  quadratic  0.405190  0.310498
#
#     Precision  k
# 21   0.189222  5
# 9    0.192814  5
# 20   0.188024  5
# 7    0.189222  5
# 16   0.186826  5
# 17   0.185629  5
# 14   0.194012  5
# 11   0.191617  5
# 8    0.190419  5
# 6    0.194012  5

# %%
scores_frame.sort_values('Precision', ascending=False).head(10)
# Out:
#    session weighting items weighting    ranking       MRR    Recall  \
# 2             random          linear  quadratic  0.393812  0.309103
# 14            recent          linear  quadratic  0.399501  0.311288
# 6             random             log  quadratic  0.405190  0.310498
# 9             random       quadratic        log  0.392116  0.313864
# 10            random       quadratic  quadratic  0.400998  0.309200
# 11            random       quadratic        inv  0.397106  0.311154
# 22            recent       quadratic  quadratic  0.407385  0.308877
# 18            recent             log  quadratic  0.406088  0.310018
# 8             random       quadratic     linear  0.387425  0.310570
# 7             random             log        inv  0.391517  0.311515
#
#     Precision  k
# 2    0.195210  5
# 14   0.194012  5
# 6    0.194012  5
# 9    0.192814  5
# 10   0.192814  5
# 11   0.191617  5
# 22   0.190419  5
# 18   0.190419  5
# 8    0.190419  5
# 7    0.189222  5

# %%
scores_frame[['MRR', 'Precision', 'Recall']].describe()
# Out:
#              MRR  Precision     Recall
# count  36.000000  36.000000  36.000000
# mean    0.392124   0.186261   0.300570
# std     0.007899   0.004871   0.011251
# min     0.378144   0.177246   0.281337
# 25%     0.386901   0.183234   0.287951
# 50%     0.391816   0.186826   0.306240
# 75%     0.397854   0.189521   0.310516
# max     0.407385   0.195210   0.313971
